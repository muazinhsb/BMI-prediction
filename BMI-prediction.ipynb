# %% [markdown]
# ## Linear Regression with Pima women dataset

# %% [markdown]
# ### Import libraries

# %%
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load dataset

# %%
# %matplotlib notebook
pima = data('Pima.tr')
pima.head()
# Out:
#    npreg  glu  bp  skin   bmi    ped  age type
# 1      5   86  68    28  30.2  0.364   24   No
# 2      7  195  70    33  25.1  0.163   55  Yes
# 3      5   77  82    41  35.8  0.156   35   No
# 4      0  165  76    43  47.9  0.259   26   No
# 5      0  107  60    25  26.4  0.133   23   No

# %%
pima.plot(kind='scatter', x='skin', y='bmi')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Train test split for Supervised training

# %%
x_train, x_test, y_train, y_test = train_test_split(pima.skin, pima.bmi)

# %% [markdown]
# ### Train test split Visualization

# %%
plt.scatter(x_train, y_train, label='Training Data', color='r', alpha=.7)
plt.scatter(x_test, y_test, label='Testing Data', color='g', alpha=.7)
plt.legend()
plt.title("Train Test Split")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Creating Linear Model

# %%
LR = LinearRegression()
LR.fit(x_train.values.reshape(-1,1), y_train.values)
# Out:
# LinearRegression()

# %% [markdown]
# ### Use model to Test data

# %%
pred = LR.predict(x_test.values.reshape(-1, 1))

# %% [markdown]
# ### Plot prediction line against the actual test data

# %%
plt.plot(x_test, pred, label='Linear Regression', color='b')
plt.scatter(x_test, y_test, label='Actual Test Data', color='g', alpha=.7)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Predict BMI of woman based on skin fold

# %%
LR.predict(np.array([[50]]))[0]
# Out:
# 38.996804268065716

# %%
LR.predict(np.array([[40]]))[0]
# Out:
# 35.715957961030675

# %%
LR.predict(np.array([[30]]))[0]
# Out:
# 32.435111653995634

# %% [markdown]
# ### Score the model

# %%
LR.score(x_test.values.reshape(-1, 1), y_test.values)
# Out:
# 0.43023235183315756
